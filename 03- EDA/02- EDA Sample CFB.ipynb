# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import os

# %matplotlib inline

# %%
data_file = os.path.join('D:', os.path.sep, 'Datasets', 'general', 'cfb','cfb19.csv')
data_file
# Out:
# 'D:\\Datasets\\general\\cfb\\cfb19.csv'

# %%
df = pd.read_csv(data_file)

# %%
df.head()
# Out:
#                          Team  Games  Win  Loss  Off.Rank  Off.Plays  \
# 0   Air Force (Mountain West)     13   11     2        51        881
# 1                 Akron (MAC)     12    0    12       130        725
# 2               Alabama (SEC)     13   11     2         6        842
# 3  Appalachian St. (Sun Belt)     14   13     1        39        969
# 4            Arizona (Pac-12)     12    4     8        30        873
#
#    Off.Yards  Off.Yards.Play  Off.TDs  Off.Yards.per.Game  ...  \
# 0       5483            6.22       55               421.8  ...
# 1       2918            4.02       14               243.2  ...
# 2       6640            7.89       76               510.8  ...
# 3       6064            6.26       65               433.1  ...
# 4       5281            6.05       42               440.1  ...
#
#    Average.Time.of.Possession.per.Game  Turnover.Rank  Fumbles.Recovered  \
# 0                                34:28             78                  9
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Columns: 152 entries, Team to Avg.Turnover.Margin.per.Game
# dtypes: float64(30), int64(119), object(3)
# memory usage: 154.5+ KB

# %%
df.columns[df.columns.str.contains('W')]
# Out:
# Index(['Win'], dtype='object')

# %%
df[['Win']] = df[['Win']].apply(pd.to_numeric, errors='coerce')

# %%
team = df[['Team']]
team
# Out:
#                            Team
# 0     Air Force (Mountain West)
# 1                   Akron (MAC)
# 2                 Alabama (SEC)
# 3    Appalachian St. (Sun Belt)
# 4              Arizona (Pac-12)
# ..                          ...
# 125      West Virginia (Big 12)
# 126         Western Ky. (C-USA)
# 127         Western Mich. (MAC)
# 128         Wisconsin (Big Ten)
# 129     Wyoming (Mountain West)
#
# [130 rows x 1 columns]

# %%
df_corr = df.corr(numeric_only=True)
df_corr
# Out:
#                                  Games       Win      Loss  Off.Rank  \
# Games                         1.000000  0.867916 -0.783464 -0.428834
# Win                           0.867916  1.000000 -0.988655 -0.547510
# Loss                         -0.783464 -0.988655  1.000000  0.555317
# Off.Rank                     -0.428834 -0.547510  0.555317  1.000000
# Off.Plays                     0.723447  0.715855 -0.676846 -0.690523
# ...                                ...       ...       ...       ...
# Fumbles.Lost                  0.081529 -0.015865  0.044502 -0.021580
# Interceptions.Thrown.y       -0.189599 -0.370948  0.406763  0.234430
# Turnovers.Lost               -0.098361 -0.305809  0.352856  0.172833
# Turnover.Margin               0.374522  0.545360 -0.569051 -0.302050
# Avg.Turnover.Margin.per.Game  0.373135  0.544279 -0.568118 -0.307953
#
#                               Off.Plays  Off.Yards  Off.Yards.Play   Off.TDs  \
# ...

# %%
sns.heatmap(df_corr)
# Out:
# <Axes: >

# %%
df_corr['Win']['Off.Rank']
# Out:
# -0.5475100126724369

# %%
df_factors = df_corr[df_corr['Win'] >= 0.70] # [['Win']] * 100
df_factors
# Out:
#                      Games       Win      Loss  Off.Rank  Off.Plays  \
# Games             1.000000  0.867916 -0.783464 -0.428834   0.723447
# Win               0.867916  1.000000 -0.988655 -0.547510   0.715855
# Off.Plays         0.723447  0.715855 -0.676846 -0.690523   1.000000
# Off.Yards         0.718941  0.773414 -0.750221 -0.905449   0.816114
# Off.TDs           0.692083  0.774386 -0.759559 -0.830671   0.710931
# Redzone.Attempts  0.681399  0.733191 -0.711250 -0.713753   0.760233
# Redzone.Scores    0.698976  0.771868 -0.754324 -0.723100   0.743658
# Touchdowns        0.713648  0.800132 -0.785248 -0.813150   0.712858
# PAT               0.719355  0.811616 -0.797891 -0.796595   0.716262
# Total.Points      0.743258  0.836112 -0.821310 -0.815548   0.751397
# Points.Per.Game   0.613020  0.763336 -0.769643 -0.853910   0.697639
#
#                   Off.Yards  Off.Yards.Play   Off.TDs  Off.Yards.per.Game  \
# Games              0.718941        0.546691  0.692083            0.482371
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df_factors[df_factors.index], cmap='magma', annot=True, square=True)
# Out:
# <Axes: >

# %%
df[df_factors.index]
# Out:
#      Games  Win  Off.Plays  Off.Yards  Off.TDs  Redzone.Attempts  \
# 0       13   11        881       5483       55                54
# 1       12    0        725       2918       14                26
# 2       13   11        842       6640       76                62
# 3       14   13        969       6064       65                60
# 4       12    4        873       5281       42                35
# ..     ...  ...        ...        ...      ...               ...
# 125     12    5        788       3863       28                34
# 126     13    9        900       5041       38                50
# 127     13    7        916       5794       56                55
# 128     14   10        963       6065       56                54
# 129     13    8        831       4562       38                45
#
#      Redzone.Scores  Touchdowns  PAT  Total.Points  Points.Per.Game
# 0                48          58   52           443             34.1
# ...

# %%
df_factors.index
# Out:
# Index(['Games', 'Win', 'Off.Plays', 'Off.Yards', 'Off.TDs', 'Redzone.Attempts',
#        'Redzone.Scores', 'Touchdowns', 'PAT', 'Total.Points',
#        'Points.Per.Game'],
#       dtype='object')

# %%
sns.pairplot(data=df[df_factors.index])
