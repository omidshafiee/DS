# %%
import numpy as np
import pandas as pd
import os

from sklearn.metrics import average_precision_score

import pycaret
from pycaret.classification import *
from infra_utils import get_raw_data

# %%
data_file = ('dataset' +  os.path.sep +  'creditcard.csv')
data_file
# Out:
# 'dataset\\creditcard.csv'

# %%
df = pd.read_csv(data_file)

# %%
df_train, df_test = get_raw_data(df)

# %%
# %%time

# pycaret.classification library:

clf1 = setup(data=df_train,
             verbose=True,
             target='target',
             log_experiment=True,
             use_gpu=False,
             experiment_name='Tuned_Model',
             fix_imbalance=True,
             # transformation=True, error
             polynomial_features=True,
             # feature_selection=True, error
             #remove_multicollinearity=True,
             #multicollinearity_threshold=0.6,
             pca=False
             
            )


add_metric(id='apc', name='APC', score_func=average_precision_score, target='pred_proba')

best_model = pycaret.classification.compare_models(sort='APC',
                                                   include=['et', 'rf', 'lr', 'gbc'],
                                                   probability_threshold=0.5
                                                  )
# Out:
# <style type="text/css">
# #T_76d8d_row8_col1, #T_76d8d_row12_col1, #T_76d8d_row14_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_76d8d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76d8d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_76d8d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76d8d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_76d8d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_76d8d_row0_col1" class="data row0 col1" >6275</td>
#     </tr>
#     <tr>
#       <th id="T_76d8d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_76d8d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_76d8d_row1_col1" class="data row1 col1" >target</td>
#     </tr>
#     <tr>
#       <th id="T_76d8d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_76d8d_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_76d8d_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_76d8d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_76d8d_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_76d8d_row3_col1" class="data row3 col1" >(2237, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_76d8d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_76d8d_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_76d8d_row4_col1" class="data row4 col1" >(3352, 496)</td>
#     </tr>
#     <tr>
#       <th id="T_76d8d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_76d8d_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_76d8d_row5_col1" class="data row5 col1" >(2680, 496)</td>
#     </tr>
#     <tr>
#       <th id="T_76d8d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_76d8d_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_76d8d_row6_col1" class="data row6 col1" >(672, 496)</td>
#     </tr>
#     <tr>
#       <th id="T_76d8d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_76d8d_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_76d8d_row7_col1" class="data row7 col1" >30</td>
#     </tr>
#     <tr>
#       <th id="T_76d8d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_76d8d_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_76d8d_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_76d8d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_76d8d_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_76d8d_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_76d8d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_76d8d_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_76d8d_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_76d8d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_76d8d_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_76d8d_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_76d8d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_76d8d_row12_col0" class="data row12 col0" >Polynomial features</td>
#       <td id="T_76d8d_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_76d8d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_76d8d_row13_col0" class="data row13 col0" >Polynomial degree</td>
#       <td id="T_76d8d_row13_col1" class="data row13 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_76d8d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_76d8d_row14_col0" class="data row14 col0" >Fix imbalance</td>
#       <td id="T_76d8d_row14_col1" class="data row14 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_76d8d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_76d8d_row15_col0" class="data row15 col0" >Fix imbalance method</td>
#       <td id="T_76d8d_row15_col1" class="data row15 col1" >SMOTE</td>
#     </tr>
#     <tr>
#       <th id="T_76d8d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_76d8d_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_76d8d_row16_col1" class="data row16 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_76d8d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_76d8d_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_76d8d_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_76d8d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_76d8d_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_76d8d_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_76d8d_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_76d8d_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_76d8d_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_76d8d_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_76d8d_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_76d8d_row20_col1" class="data row20 col1" >MlflowLogger</td>
#     </tr>
#     <tr>
#       <th id="T_76d8d_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_76d8d_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_76d8d_row21_col1" class="data row21 col1" >Tuned_Model</td>
#     </tr>
#     <tr>
#       <th id="T_76d8d_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_76d8d_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_76d8d_row22_col1" class="data row22 col1" >0e6a</td>
#     </tr>
#   </tbody>
# </table>
# 2024/08/03 08:44:24 INFO mlflow.tracking.fluent: Experiment with name 'Tuned_Model' does not exist. Creating a new experiment.
# <style type="text/css">
# #T_0f07c th {
#   text-align: left;
# }
# #T_0f07c_row0_col0, #T_0f07c_row0_col1, #T_0f07c_row0_col3, #T_0f07c_row0_col4, #T_0f07c_row0_col5, #T_0f07c_row0_col6, #T_0f07c_row0_col7, #T_0f07c_row1_col0, #T_0f07c_row1_col1, #T_0f07c_row1_col2, #T_0f07c_row1_col3, #T_0f07c_row1_col4, #T_0f07c_row1_col5, #T_0f07c_row1_col6, #T_0f07c_row1_col7, #T_0f07c_row1_col8, #T_0f07c_row2_col0, #T_0f07c_row2_col2, #T_0f07c_row2_col3, #T_0f07c_row2_col8, #T_0f07c_row3_col0, #T_0f07c_row3_col1, #T_0f07c_row3_col2, #T_0f07c_row3_col4, #T_0f07c_row3_col5, #T_0f07c_row3_col6, #T_0f07c_row3_col7, #T_0f07c_row3_col8 {
#   text-align: left;
# }
# #T_0f07c_row0_col2, #T_0f07c_row0_col8, #T_0f07c_row2_col1, #T_0f07c_row2_col4, #T_0f07c_row2_col5, #T_0f07c_row2_col6, #T_0f07c_row2_col7, #T_0f07c_row3_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_0f07c_row0_col9, #T_0f07c_row2_col9, #T_0f07c_row3_col9 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_0f07c_row1_col9 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_0f07c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0f07c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0f07c_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_0f07c_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_0f07c_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_0f07c_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_0f07c_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_0f07c_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_0f07c_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_0f07c_level0_col8" class="col_heading level0 col8" >APC</th>
#       <th id="T_0f07c_level0_col9" class="col_heading level0 col9" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0f07c_level0_row0" class="row_heading level0 row0" >gbc</th>
#       <td id="T_0f07c_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_0f07c_row0_col1" class="data row0 col1" >0.9700</td>
#       <td id="T_0f07c_row0_col2" class="data row0 col2" >0.9780</td>
#       <td id="T_0f07c_row0_col3" class="data row0 col3" >0.8581</td>
#       <td id="T_0f07c_row0_col4" class="data row0 col4" >0.9294</td>
#       <td id="T_0f07c_row0_col5" class="data row0 col5" >0.8905</td>
#       <td id="T_0f07c_row0_col6" class="data row0 col6" >0.8732</td>
#       <td id="T_0f07c_row0_col7" class="data row0 col7" >0.8753</td>
#       <td id="T_0f07c_row0_col8" class="data row0 col8" >0.9488</td>
#       <td id="T_0f07c_row0_col9" class="data row0 col9" >16.1760</td>
#     </tr>
#     <tr>
#       <th id="T_0f07c_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_0f07c_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_0f07c_row1_col1" class="data row1 col1" >0.9732</td>
#       <td id="T_0f07c_row1_col2" class="data row1 col2" >0.9751</td>
#       <td id="T_0f07c_row1_col3" class="data row1 col3" >0.8538</td>
#       <td id="T_0f07c_row1_col4" class="data row1 col4" >0.9586</td>
#       <td id="T_0f07c_row1_col5" class="data row1 col5" >0.9005</td>
#       <td id="T_0f07c_row1_col6" class="data row1 col6" >0.8851</td>
#       <td id="T_0f07c_row1_col7" class="data row1 col7" >0.8887</td>
#       <td id="T_0f07c_row1_col8" class="data row1 col8" >0.9433</td>
#       <td id="T_0f07c_row1_col9" class="data row1 col9" >1.1640</td>
#     </tr>
#     <tr>
#       <th id="T_0f07c_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_0f07c_row2_col0" class="data row2 col0" >Extra Trees Classifier</td>
#       <td id="T_0f07c_row2_col1" class="data row2 col1" >0.9738</td>
#       <td id="T_0f07c_row2_col2" class="data row2 col2" >0.9743</td>
#       <td id="T_0f07c_row2_col3" class="data row2 col3" >0.8494</td>
#       <td id="T_0f07c_row2_col4" class="data row2 col4" >0.9656</td>
#       <td id="T_0f07c_row2_col5" class="data row2 col5" >0.9021</td>
#       <td id="T_0f07c_row2_col6" class="data row2 col6" >0.8871</td>
#       <td id="T_0f07c_row2_col7" class="data row2 col7" >0.8906</td>
#       <td id="T_0f07c_row2_col8" class="data row2 col8" >0.9391</td>
#       <td id="T_0f07c_row2_col9" class="data row2 col9" >1.7210</td>
#     </tr>
#     <tr>
#       <th id="T_0f07c_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_0f07c_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_0f07c_row3_col1" class="data row3 col1" >0.9597</td>
#       <td id="T_0f07c_row3_col2" class="data row3 col2" >0.9504</td>
#       <td id="T_0f07c_row3_col3" class="data row3 col3" >0.8674</td>
#       <td id="T_0f07c_row3_col4" class="data row3 col4" >0.8588</td>
#       <td id="T_0f07c_row3_col5" class="data row3 col5" >0.8607</td>
#       <td id="T_0f07c_row3_col6" class="data row3 col6" >0.8373</td>
#       <td id="T_0f07c_row3_col7" class="data row3 col7" >0.8388</td>
#       <td id="T_0f07c_row3_col8" class="data row3 col8" >0.9179</td>
#       <td id="T_0f07c_row3_col9" class="data row3 col9" >1.3370</td>
#     </tr>
#   </tbody>
# </table>
# CPU times: total: 1min
# Wall time: 4min 32s

# %%
best_model
# Out:
# CustomProbabilityThresholdClassifier(ccp_alpha=0.0,
#                                      classifier=GradientBoostingClassifier(ccp_alpha=0.0,
#                                                                            criterion='friedman_mse',
#                                                                            init=None,
#                                                                            learning_rate=0.1,
#                                                                            loss='log_loss',
#                                                                            max_depth=3,
#                                                                            max_features=None,
#                                                                            max_leaf_nodes=None,
#                                                                            min_impurity_decrease=0.0,
#                                                                            min_samples_leaf=1,
#                                                                            min_samples_split=2,
#                                                                            min_weight_fraction_leaf=0.0,
#                                                                            n_estimators=100,
#                                                                            n_iter_no_change=...
#                                      criterion='friedman_mse', init=None,
#                                      learning_rate=0.1, loss='log_loss',
#                                      max_depth=3, max_features=None,
#                                      max_leaf_nodes=None,
#                                      min_impurity_decrease=0.0,
#                                      min_samples_leaf=1, min_samples_split=2,
#                                      min_weight_fraction_leaf=0.0,
#                                      n_estimators=100, n_iter_no_change=None,
#                                      probability_threshold=0.5,
#                                      random_state=6275, subsample=1.0,
#                                      tol=0.0001, validation_fraction=0.1,
#                                      verbose=0, warm_start=False)

# %% [markdown]
# ## Hyperparameter Tuning
# ### Define search space for hepyer paramater tuning

# %%
# %%time
params = {'max_depth': np.random.randint(1, 40, 3)}
#          'n_estimetor': np.random.randint(2, 1000, 10)}
params['max_depth']
# Tune Model

tuned_dt = pycaret.classification.tune_model(best_model, custom_grid=params)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      09:01:13
# Status     . . . . . . . . . . . . . . . . . .     Searching Hyperparameters
# Estimator  . . . . . . . . . . . . . . . . . .  Gradient Boosting Classifier
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 3 candidates, totalling 30 fits

# %%
tuned_dt
# Out:
# CustomProbabilityThresholdClassifier(bootstrap=False, ccp_alpha=0.0,
#                                      class_weight=None,
#                                      classifier=ExtraTreesClassifier(bootstrap=False,
#                                                                      ccp_alpha=0.0,
#                                                                      class_weight=None,
#                                                                      criterion='gini',
#                                                                      max_depth=34,
#                                                                      max_features='sqrt',
#                                                                      max_leaf_nodes=None,
#                                                                      max_samples=None,
#                                                                      min_impurity_decrease=0.0,
#                                                                      min_samples_leaf=1,
#                                                                      min_samples_split=2,
#                                                                      min_weight_fraction_leaf=0.0,
#                                                                      mono...
#                                                                      random_state=3098,
#                                                                      verbose=0,
#                                                                      warm_start=False),
#                                      criterion='gini', max_depth=34,
#                                      max_features='sqrt', max_leaf_nodes=None,
#                                      max_samples=None,
#                                      min_impurity_decrease=0.0,
#                                      min_samples_leaf=1, min_samples_split=2,
#                                      min_weight_fraction_leaf=0.0,
#                                      monotonic_cst=None, n_estimators=100,
#                                      n_jobs=-1, oob_score=False,
#                                      probability_threshold=0.5,
#                                      random_state=3098, verbose=0,
#                                      warm_start=False)

# %%
result = predict_model(tuned_dt, data=df_test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e0a88">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e0a88_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e0a88_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_e0a88_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_e0a88_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_e0a88_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_e0a88_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_e0a88_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_e0a88_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_e0a88_level0_col8" class="col_heading level0 col8" >APC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0a88_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e0a88_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_e0a88_row0_col1" class="data row0 col1" >0.9737</td>
#       <td id="T_e0a88_row0_col2" class="data row0 col2" >0.9684</td>
#       <td id="T_e0a88_row0_col3" class="data row0 col3" >0.8538</td>
#       <td id="T_e0a88_row0_col4" class="data row0 col4" >0.9733</td>
#       <td id="T_e0a88_row0_col5" class="data row0 col5" >0.9097</td>
#       <td id="T_e0a88_row0_col6" class="data row0 col6" >0.8943</td>
#       <td id="T_e0a88_row0_col7" class="data row0 col7" >0.8970</td>
#       <td id="T_e0a88_row0_col8" class="data row0 col8" >0.9376</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Voting Classifier

# %%
tops = compare_models(n_select=3, sort='APC')
tops
# Out:
# <style type="text/css">
# #T_ac686 th {
#   text-align: left;
# }
# #T_ac686_row0_col0, #T_ac686_row0_col1, #T_ac686_row0_col3, #T_ac686_row0_col4, #T_ac686_row0_col5, #T_ac686_row0_col6, #T_ac686_row0_col7, #T_ac686_row1_col0, #T_ac686_row1_col1, #T_ac686_row1_col2, #T_ac686_row1_col3, #T_ac686_row1_col4, #T_ac686_row1_col5, #T_ac686_row1_col6, #T_ac686_row1_col7, #T_ac686_row1_col8, #T_ac686_row2_col0, #T_ac686_row2_col2, #T_ac686_row2_col3, #T_ac686_row2_col4, #T_ac686_row2_col8, #T_ac686_row3_col0, #T_ac686_row3_col1, #T_ac686_row3_col2, #T_ac686_row3_col3, #T_ac686_row3_col4, #T_ac686_row3_col5, #T_ac686_row3_col6, #T_ac686_row3_col7, #T_ac686_row3_col8, #T_ac686_row4_col0, #T_ac686_row4_col1, #T_ac686_row4_col2, #T_ac686_row4_col3, #T_ac686_row4_col4, #T_ac686_row4_col5, #T_ac686_row4_col6, #T_ac686_row4_col7, #T_ac686_row4_col8, #T_ac686_row5_col0, #T_ac686_row5_col1, #T_ac686_row5_col2, #T_ac686_row5_col3, #T_ac686_row5_col4, #T_ac686_row5_col5, #T_ac686_row5_col6, #T_ac686_row5_col7, #T_ac686_row5_col8, #T_ac686_row6_col0, #T_ac686_row6_col1, #T_ac686_row6_col2, #T_ac686_row6_col4, #T_ac686_row6_col5, #T_ac686_row6_col6, #T_ac686_row6_col7, #T_ac686_row6_col8, #T_ac686_row7_col0, #T_ac686_row7_col1, #T_ac686_row7_col2, #T_ac686_row7_col3, #T_ac686_row7_col4, #T_ac686_row7_col5, #T_ac686_row7_col6, #T_ac686_row7_col7, #T_ac686_row7_col8, #T_ac686_row8_col0, #T_ac686_row8_col1, #T_ac686_row8_col2, #T_ac686_row8_col3, #T_ac686_row8_col5, #T_ac686_row8_col6, #T_ac686_row8_col7, #T_ac686_row8_col8, #T_ac686_row9_col0, #T_ac686_row9_col1, #T_ac686_row9_col2, #T_ac686_row9_col3, #T_ac686_row9_col4, #T_ac686_row9_col5, #T_ac686_row9_col6, #T_ac686_row9_col7, #T_ac686_row9_col8, #T_ac686_row10_col0, #T_ac686_row10_col1, #T_ac686_row10_col2, #T_ac686_row10_col3, #T_ac686_row10_col4, #T_ac686_row10_col5, #T_ac686_row10_col6, #T_ac686_row10_col7, #T_ac686_row10_col8, #T_ac686_row11_col0, #T_ac686_row11_col1, #T_ac686_row11_col2, #T_ac686_row11_col3, #T_ac686_row11_col4, #T_ac686_row11_col5, #T_ac686_row11_col6, #T_ac686_row11_col7, #T_ac686_row11_col8, #T_ac686_row12_col0, #T_ac686_row12_col1, #T_ac686_row12_col2, #T_ac686_row12_col3, #T_ac686_row12_col4, #T_ac686_row12_col5, #T_ac686_row12_col6, #T_ac686_row12_col7, #T_ac686_row12_col8, #T_ac686_row13_col0, #T_ac686_row13_col1, #T_ac686_row13_col2, #T_ac686_row13_col3, #T_ac686_row13_col4, #T_ac686_row13_col5, #T_ac686_row13_col6, #T_ac686_row13_col7, #T_ac686_row13_col8, #T_ac686_row14_col0, #T_ac686_row14_col1, #T_ac686_row14_col2, #T_ac686_row14_col3, #T_ac686_row14_col4, #T_ac686_row14_col5, #T_ac686_row14_col6, #T_ac686_row14_col7, #T_ac686_row14_col8 {
#   text-align: left;
# }
# #T_ac686_row0_col2, #T_ac686_row0_col8, #T_ac686_row2_col1, #T_ac686_row2_col5, #T_ac686_row2_col6, #T_ac686_row2_col7, #T_ac686_row6_col3, #T_ac686_row8_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ac686_row0_col9, #T_ac686_row1_col9, #T_ac686_row2_col9, #T_ac686_row3_col9, #T_ac686_row4_col9, #T_ac686_row5_col9, #T_ac686_row6_col9, #T_ac686_row8_col9, #T_ac686_row9_col9, #T_ac686_row10_col9, #T_ac686_row11_col9, #T_ac686_row12_col9, #T_ac686_row13_col9, #T_ac686_row14_col9 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_ac686_row7_col9 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ac686">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ac686_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ac686_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_ac686_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_ac686_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_ac686_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_ac686_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_ac686_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_ac686_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_ac686_level0_col8" class="col_heading level0 col8" >APC</th>
#       <th id="T_ac686_level0_col9" class="col_heading level0 col9" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac686_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_ac686_row0_col0" class="data row0 col0" >CatBoost Classifier</td>
#       <td id="T_ac686_row0_col1" class="data row0 col1" >0.9738</td>
#       <td id="T_ac686_row0_col2" class="data row0 col2" >0.9822</td>
#       <td id="T_ac686_row0_col3" class="data row0 col3" >0.8625</td>
#       <td id="T_ac686_row0_col4" class="data row0 col4" >0.9512</td>
#       <td id="T_ac686_row0_col5" class="data row0 col5" >0.9025</td>
#       <td id="T_ac686_row0_col6" class="data row0 col6" >0.8875</td>
#       <td id="T_ac686_row0_col7" class="data row0 col7" >0.8903</td>
#       <td id="T_ac686_row0_col8" class="data row0 col8" >0.9525</td>
#       <td id="T_ac686_row0_col9" class="data row0 col9" >52.7260</td>
#     </tr>
#     <tr>
#       <th id="T_ac686_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_ac686_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_ac686_row1_col1" class="data row1 col1" >0.9732</td>
#       <td id="T_ac686_row1_col2" class="data row1 col2" >0.9762</td>
#       <td id="T_ac686_row1_col3" class="data row1 col3" >0.8666</td>
#       <td id="T_ac686_row1_col4" class="data row1 col4" >0.9432</td>
#       <td id="T_ac686_row1_col5" class="data row1 col5" >0.9011</td>
#       <td id="T_ac686_row1_col6" class="data row1 col6" >0.8857</td>
#       <td id="T_ac686_row1_col7" class="data row1 col7" >0.8881</td>
#       <td id="T_ac686_row1_col8" class="data row1 col8" >0.9464</td>
#       <td id="T_ac686_row1_col9" class="data row1 col9" >14.4150</td>
#     </tr>
#     <tr>
#       <th id="T_ac686_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_ac686_row2_col0" class="data row2 col0" >Extra Trees Classifier</td>
#       <td id="T_ac686_row2_col1" class="data row2 col1" >0.9776</td>
#       <td id="T_ac686_row2_col2" class="data row2 col2" >0.9775</td>
#       <td id="T_ac686_row2_col3" class="data row2 col3" >0.8577</td>
#       <td id="T_ac686_row2_col4" class="data row2 col4" >0.9861</td>
#       <td id="T_ac686_row2_col5" class="data row2 col5" >0.9151</td>
#       <td id="T_ac686_row2_col6" class="data row2 col6" >0.9024</td>
#       <td id="T_ac686_row2_col7" class="data row2 col7" >0.9067</td>
#       <td id="T_ac686_row2_col8" class="data row2 col8" >0.9458</td>
#       <td id="T_ac686_row2_col9" class="data row2 col9" >0.2420</td>
#     </tr>
#     <tr>
#       <th id="T_ac686_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_ac686_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_ac686_row3_col1" class="data row3 col1" >0.9751</td>
#       <td id="T_ac686_row3_col2" class="data row3 col2" >0.9781</td>
#       <td id="T_ac686_row3_col3" class="data row3 col3" >0.8536</td>
#       <td id="T_ac686_row3_col4" class="data row3 col4" >0.9703</td>
#       <td id="T_ac686_row3_col5" class="data row3 col5" >0.9056</td>
#       <td id="T_ac686_row3_col6" class="data row3 col6" >0.8915</td>
#       <td id="T_ac686_row3_col7" class="data row3 col7" >0.8955</td>
#       <td id="T_ac686_row3_col8" class="data row3 col8" >0.9453</td>
#       <td id="T_ac686_row3_col9" class="data row3 col9" >1.8060</td>
#     </tr>
#     <tr>
#       <th id="T_ac686_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_ac686_row4_col0" class="data row4 col0" >Random Forest Classifier</td>
#       <td id="T_ac686_row4_col1" class="data row4 col1" >0.9770</td>
#       <td id="T_ac686_row4_col2" class="data row4 col2" >0.9772</td>
#       <td id="T_ac686_row4_col3" class="data row4 col3" >0.8713</td>
#       <td id="T_ac686_row4_col4" class="data row4 col4" >0.9685</td>
#       <td id="T_ac686_row4_col5" class="data row4 col5" >0.9146</td>
#       <td id="T_ac68
# 2024/08/02 20:52:38 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 2024/08/02 20:53:48 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 2024/08/02 20:53:50 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 2024/08/02 20:53:50 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 2024/08/02 20:53:51 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 2024/08/02 20:53:51 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 2024/08/02 20:53:52 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 2024/08/02 20:53:53 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 2024/08/02 20:53:53 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 2024/08/02 20:53:54 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 2024/08/02 20:53:54 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 2024/08/02 20:53:55 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 2024/08/02 20:53:55 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 2024/08/02 20:53:56 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 2024/08/02 20:53:56 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# [<catboost.core.CatBoostClassifier at 0x215c8f8f4d0>,
#  GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                             learning_rate=0.1, loss='log_loss', max_depth=3,
#                             max_features=None, max_leaf_nodes=None,
#                             min_impurity_decrease=0.0, min_samples_leaf=1,
#                             min_samples_split=2, min_weight_fraction_leaf=0.0,
#                             n_estimators=100, n_iter_no_change=None,
#                             random_state=3098, subsample=1.0, tol=0.0001,
#                             validation_fraction=0.1, verbose=0,
#                             warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                       criterion='gini', max_depth=None, max_features='sqrt',
#                       max_leaf_nodes=None, max_samples=None,
#                       min_impurity_decrease=0.0, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       monotonic_cst=None, n_estimators=100, n_jobs=-1,
#                       oob_score=False, random_state=3098, verbose=0,
#                       warm_start=False)]

# %%
tops[1]
# Out:
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='log_loss', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_samples_leaf=1,
#                            min_samples_split=2, min_weight_fraction_leaf=0.0,
#                            n_estimators=100, n_iter_no_change=None,
#                            random_state=3098, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
# %%time
bledned_weights = blend_models([tops[0], tops[1], tops[2]], weights=[0.5, 0.3, 0.2])
# Out:
# <style type="text/css">
# #T_dd53a_row10_col0, #T_dd53a_row10_col1, #T_dd53a_row10_col2, #T_dd53a_row10_col3, #T_dd53a_row10_col4, #T_dd53a_row10_col5, #T_dd53a_row10_col6, #T_dd53a_row10_col7 {
#   background: yellow;
# }
# </style>
# <table id="T_dd53a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dd53a_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_dd53a_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_dd53a_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_dd53a_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_dd53a_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_dd53a_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_dd53a_level0_col6" class="col_heading level0 col6" >MCC</th>
#       <th id="T_dd53a_level0_col7" class="col_heading level0 col7" >APC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd53a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dd53a_row0_col0" class="data row0 col0" >0.9745</td>
#       <td id="T_dd53a_row0_col1" class="data row0 col1" >0.9760</td>
#       <td id="T_dd53a_row0_col2" class="data row0 col2" >0.8261</td>
#       <td id="T_dd53a_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_dd53a_row0_col4" class="data row0 col4" >0.9048</td>
#       <td id="T_dd53a_row0_col5" class="data row0 col5" >0.8902</td>
#       <td id="T_dd53a_row0_col6" class="data row0 col6" >0.8956</td>
#       <td id="T_dd53a_row0_col7" class="data row0 col7" >0.9404</td>
#     </tr>
#     <tr>
#       <th id="T_dd53a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dd53a_row1_col0" class="data row1 col0" >0.9745</td>
#       <td id="T_dd53a_row1_col1" class="data row1 col1" >0.9721</td>
#       <td id="T_dd53a_row1_col2" class="data row1 col2" >0.8696</td>
#       <td id="T_dd53a_row1_col3" class="data row1 col3" >0.9524</td>
#       <td id="T_dd53a_row1_col4" class="data row1 col4" >0.9091</td>
#       <td id="T_dd53a_row1_col5" class="data row1 col5" >0.8943</td>
#       <td id="T_dd53a_row1_col6" class="data row1 col6" >0.8956</td>
#       <td id="T_dd53a_row1_col7" class="data row1 col7" >0.9522</td>
#     </tr>
#     <tr>
#       <th id="T_dd53a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dd53a_row2_col0" class="data row2 col0" >0.9873</td>
#       <td id="T_dd53a_row2_col1" class="data row2 col1" >0.9974</td>
#       <td id="T_dd53a_row2_col2" class="data row2 col2" >0.9130</td>
#       <td id="T_dd53a_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_dd53a_row2_col4" class="data row2 col4" >0.9545</td>
#       <td id="T_dd53a_row2_col5" class="data row2 col5" >0.9472</td>
#       <td id="T_dd53a_row2_col6" class="data row2 col6" >0.9485</td>
#       <td id="T_dd53a_row2_col7" class="data row2 col7" >0.9888</td>
#     </tr>
#     <tr>
#       <th id="T_dd53a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dd53a_row3_col0" class="data row3 col0" >0.9809</td>
#       <td id="T_dd53a_row3_col1" class="data row3 col1" >0.9880</td>
#       <td id="T_dd53a_row3_col2" class="data row3 col2" >0.8696</td>
#       <td id="T_dd53a_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_dd53a_row3_col4" class="data row3 col4" >0.9302</td>
#       <td id="T_dd53a_row3_col5" class="data row3 col5" >0.9192</td>
#       <td id="T_dd53a_row3_col6" class="data row3 col6" >0.9222</td>
#       <td id="T_dd53a_row3_col7" class="data row3 col7" >0.9536</td>
#     </tr>
#     <tr>
#       <th id="T_dd53a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dd53a_row4_col0" class="data row4 col0" >0.9682</td>
#       <td id="T_dd53a_row4_col1" class="data row4 col1" >0.9536</td>
#       <td id="T_dd53a_row4_col2" class="data row4 col2" >0.8261</td>
#       <td id="T_dd53a_row4_col3" class="data row4 col3" >0.9500</td>
#       <td id="T_dd53a_row4_col4" class="data row4 col4" >0.8837</td>
#       <td id="T_dd53a_row4_col5" class="data row4 col5" >0.8654</td>
#       <td id="T_dd53a_row4_col6" class="data row4 col6" >0.8682</td>
#       <td id="T_dd53a_row4_col7" class="data row4 col7" >0.9075</td>
#     </tr>
#     <tr>
#       <th id="T_dd53a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dd53a_row5_col0" class="data row5 col0" >0.9808</td>
#       <td id="T_dd53a_row5_col1" class="data row5 col1" >0.9942</td>
#       <td id="T_dd53a_row5_col2" class="data row5 col2" >0.9545</td>
#       <td id="T_dd53a_row5_col3" class="data row5 col3" >0.9130</td>
#       <td id="T_dd53a_row5_col4" class="data row5 col4" >0.9333</td>
#       <td id="T_dd53a_row5_col5" class="data row5 col5" >0.9221</td>
#       <td id="T_dd53a_row5_col6" class="data row5 col6" >0.9224</td>
#       <td id="T_dd53a_row5_col7" class="data row5 col7" >0.9788</td>
#     </tr>
#     <tr>
#       <th id="T_dd53a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dd53a_row6_col0" class="data row6 col0" >0.9808</td>
#       <td id="T_dd53a_row6_col1" class="data row6 col1" >0.9810</td>
#       <td id="T_dd53a_row6_col2" class="data row6 col2" >0.9091</td>
#       <td id="T_dd53a_row6_col3" class="data row6 col3" >0.9524</td>
#       <td id="T_dd53a_row6_col4" class="data row6 col4" >0.9302</td>
#       <td id="T_dd53a_row6_col5" class="data row6 col5" >0.9191</td>
#       <td id="T_dd53a_row6_col6" class="data row6 col6" >0.9194</td>
#       <td id="T_dd53a_row6_col7" class="data row6 col7" >0.9486</td>
#     </tr>
#     <tr>
#       <th id="T_dd53a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_dd53a_row7_col0" class="data row7 col0" >0.9679</td>
#       <td id="T_dd53a_row7_col1" class="data row7 col1" >0.9824</td>
#       <td id="T_dd53a_row7_col2" class="data row7 col2" >0.8636</td>
#       <td id="T_dd53a_row7_col3" class="data row7 col3" >0.9048</td>
#       <td id="T_dd53a_row7_col4" class="data row7 col4" >0.8837</td>
#       <td id="T_dd53a_row7_col5" class="data row7 col5" >0.8651</td>
#       <td id="T_dd53a_row7_col6" class="data row7 col6" >0.8655</td>
#       <td id="T_dd53a_row7_col7" class="data row7 col7" >0.9475</td>
#     </tr>
#     <tr>
#       <th id="T_dd53a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_dd53a_row8_col0" class="data row8 col0" >0.9936</td>
#       <td id="T_dd53a_row8_col1" class="data row8 col1" >0.9990</td>
#       <td id="T_dd53a_row8_col2" class="data row8 col2" >0.9545</td>
#       <td id="T_dd53a_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_dd53a_row8_col4" class="data row8 col4" >0.9767</td>
#       <td id="T_dd53a_row8_col5" class="data row8 col5" >0.9730</td>
#       <td id="T_dd53a_row8_col6" class="data row8 col6" >0.9734</td>
#       <td id="T_dd53a_row8_col7" class="data row8 col7" >0.9945</td>
#     </tr>
#     <tr>
#       <th id="T_dd53a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_dd53a_row9_col0" class="data row9 col0" >0.9487</td>
#       <td id="T_dd53a_row9_col1" class="data row9 col1" >0.9671</td>
#       <td id="T_dd53a_row9_col2" class="data row9 col2" >0.6818</td>
#       <td id="T_dd53a_row9_col3" class="data row9 col3" >0.9375</td>
#       <td id="T_dd53a_row9_col4" class="data row9 col4" >0.7895</td>
#       <td id="T_dd53a_row9_col5" class="data row9 col5" >0.7611</td>
#       <td id="T_dd53a_row9_col6" class="data row9 col6" >0.7736</td>
#       <td id="T_dd53a_row9_col7" class="data row9 col7" >0.8963</td>
#     </tr>
#     <tr>
#       <th id="T_dd53a_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_dd53a_row10_col0" class="data row10 col0" >0.9757</td>
#       <td
# 2024/08/02 21:11:46 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.

# %%
# %%time
blender = blend_models(tops)
# Out:
# <style type="text/css">
# #T_80bab_row10_col0, #T_80bab_row10_col1, #T_80bab_row10_col2, #T_80bab_row10_col3, #T_80bab_row10_col4, #T_80bab_row10_col5, #T_80bab_row10_col6, #T_80bab_row10_col7 {
#   background: yellow;
# }
# </style>
# <table id="T_80bab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80bab_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_80bab_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_80bab_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_80bab_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_80bab_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_80bab_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_80bab_level0_col6" class="col_heading level0 col6" >MCC</th>
#       <th id="T_80bab_level0_col7" class="col_heading level0 col7" >APC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80bab_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_80bab_row0_col0" class="data row0 col0" >0.9745</td>
#       <td id="T_80bab_row0_col1" class="data row0 col1" >0.9796</td>
#       <td id="T_80bab_row0_col2" class="data row0 col2" >0.8261</td>
#       <td id="T_80bab_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_80bab_row0_col4" class="data row0 col4" >0.9048</td>
#       <td id="T_80bab_row0_col5" class="data row0 col5" >0.8902</td>
#       <td id="T_80bab_row0_col6" class="data row0 col6" >0.8956</td>
#       <td id="T_80bab_row0_col7" class="data row0 col7" >0.9407</td>
#     </tr>
#     <tr>
#       <th id="T_80bab_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_80bab_row1_col0" class="data row1 col0" >0.9745</td>
#       <td id="T_80bab_row1_col1" class="data row1 col1" >0.9870</td>
#       <td id="T_80bab_row1_col2" class="data row1 col2" >0.8696</td>
#       <td id="T_80bab_row1_col3" class="data row1 col3" >0.9524</td>
#       <td id="T_80bab_row1_col4" class="data row1 col4" >0.9091</td>
#       <td id="T_80bab_row1_col5" class="data row1 col5" >0.8943</td>
#       <td id="T_80bab_row1_col6" class="data row1 col6" >0.8956</td>
#       <td id="T_80bab_row1_col7" class="data row1 col7" >0.9587</td>
#     </tr>
#     <tr>
#       <th id="T_80bab_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_80bab_row2_col0" class="data row2 col0" >0.9936</td>
#       <td id="T_80bab_row2_col1" class="data row2 col1" >0.9955</td>
#       <td id="T_80bab_row2_col2" class="data row2 col2" >0.9565</td>
#       <td id="T_80bab_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_80bab_row2_col4" class="data row2 col4" >0.9778</td>
#       <td id="T_80bab_row2_col5" class="data row2 col5" >0.9741</td>
#       <td id="T_80bab_row2_col6" class="data row2 col6" >0.9744</td>
#       <td id="T_80bab_row2_col7" class="data row2 col7" >0.9835</td>
#     </tr>
#     <tr>
#       <th id="T_80bab_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_80bab_row3_col0" class="data row3 col0" >0.9809</td>
#       <td id="T_80bab_row3_col1" class="data row3 col1" >0.9893</td>
#       <td id="T_80bab_row3_col2" class="data row3 col2" >0.8696</td>
#       <td id="T_80bab_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_80bab_row3_col4" class="data row3 col4" >0.9302</td>
#       <td id="T_80bab_row3_col5" class="data row3 col5" >0.9192</td>
#       <td id="T_80bab_row3_col6" class="data row3 col6" >0.9222</td>
#       <td id="T_80bab_row3_col7" class="data row3 col7" >0.9593</td>
#     </tr>
#     <tr>
#       <th id="T_80bab_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_80bab_row4_col0" class="data row4 col0" >0.9682</td>
#       <td id="T_80bab_row4_col1" class="data row4 col1" >0.9575</td>
#       <td id="T_80bab_row4_col2" class="data row4 col2" >0.8261</td>
#       <td id="T_80bab_row4_col3" class="data row4 col3" >0.9500</td>
#       <td id="T_80bab_row4_col4" class="data row4 col4" >0.8837</td>
#       <td id="T_80bab_row4_col5" class="data row4 col5" >0.8654</td>
#       <td id="T_80bab_row4_col6" class="data row4 col6" >0.8682</td>
#       <td id="T_80bab_row4_col7" class="data row4 col7" >0.9075</td>
#     </tr>
#     <tr>
#       <th id="T_80bab_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_80bab_row5_col0" class="data row5 col0" >0.9808</td>
#       <td id="T_80bab_row5_col1" class="data row5 col1" >0.9847</td>
#       <td id="T_80bab_row5_col2" class="data row5 col2" >0.9545</td>
#       <td id="T_80bab_row5_col3" class="data row5 col3" >0.9130</td>
#       <td id="T_80bab_row5_col4" class="data row5 col4" >0.9333</td>
#       <td id="T_80bab_row5_col5" class="data row5 col5" >0.9221</td>
#       <td id="T_80bab_row5_col6" class="data row5 col6" >0.9224</td>
#       <td id="T_80bab_row5_col7" class="data row5 col7" >0.9660</td>
#     </tr>
#     <tr>
#       <th id="T_80bab_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_80bab_row6_col0" class="data row6 col0" >0.9808</td>
#       <td id="T_80bab_row6_col1" class="data row6 col1" >0.9780</td>
#       <td id="T_80bab_row6_col2" class="data row6 col2" >0.9091</td>
#       <td id="T_80bab_row6_col3" class="data row6 col3" >0.9524</td>
#       <td id="T_80bab_row6_col4" class="data row6 col4" >0.9302</td>
#       <td id="T_80bab_row6_col5" class="data row6 col5" >0.9191</td>
#       <td id="T_80bab_row6_col6" class="data row6 col6" >0.9194</td>
#       <td id="T_80bab_row6_col7" class="data row6 col7" >0.9455</td>
#     </tr>
#     <tr>
#       <th id="T_80bab_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_80bab_row7_col0" class="data row7 col0" >0.9744</td>
#       <td id="T_80bab_row7_col1" class="data row7 col1" >0.9766</td>
#       <td id="T_80bab_row7_col2" class="data row7 col2" >0.9091</td>
#       <td id="T_80bab_row7_col3" class="data row7 col3" >0.9091</td>
#       <td id="T_80bab_row7_col4" class="data row7 col4" >0.9091</td>
#       <td id="T_80bab_row7_col5" class="data row7 col5" >0.8942</td>
#       <td id="T_80bab_row7_col6" class="data row7 col6" >0.8942</td>
#       <td id="T_80bab_row7_col7" class="data row7 col7" >0.9450</td>
#     </tr>
#     <tr>
#       <th id="T_80bab_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_80bab_row8_col0" class="data row8 col0" >0.9936</td>
#       <td id="T_80bab_row8_col1" class="data row8 col1" >0.9986</td>
#       <td id="T_80bab_row8_col2" class="data row8 col2" >0.9545</td>
#       <td id="T_80bab_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_80bab_row8_col4" class="data row8 col4" >0.9767</td>
#       <td id="T_80bab_row8_col5" class="data row8 col5" >0.9730</td>
#       <td id="T_80bab_row8_col6" class="data row8 col6" >0.9734</td>
#       <td id="T_80bab_row8_col7" class="data row8 col7" >0.9930</td>
#     </tr>
#     <tr>
#       <th id="T_80bab_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_80bab_row9_col0" class="data row9 col0" >0.9487</td>
#       <td id="T_80bab_row9_col1" class="data row9 col1" >0.9495</td>
#       <td id="T_80bab_row9_col2" class="data row9 col2" >0.6818</td>
#       <td id="T_80bab_row9_col3" class="data row9 col3" >0.9375</td>
#       <td id="T_80bab_row9_col4" class="data row9 col4" >0.7895</td>
#       <td id="T_80bab_row9_col5" class="data row9 col5" >0.7611</td>
#       <td id="T_80bab_row9_col6" class="data row9 col6" >0.7736</td>
#       <td id="T_80bab_row9_col7" class="data row9 col7" >0.8725</td>
#     </tr>
#     <tr>
#       <th id="T_80bab_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_80bab_row10_col0" class="data row10 col0" >0.9770</td>
#       <td
# 2024/08/02 22:14:29 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.

# %% [markdown]
# ## Hyperparameter tuning with scikit-optimize on voting model

# %%
# %%time
tuned_vote = tune_model(bledned_weights, search_library='scikit-optimize', optimize='APC', n_iter=5)
# Out:
# <style type="text/css">
# #T_28f95_row10_col0, #T_28f95_row10_col1, #T_28f95_row10_col2, #T_28f95_row10_col3, #T_28f95_row10_col4, #T_28f95_row10_col5, #T_28f95_row10_col6, #T_28f95_row10_col7 {
#   background: yellow;
# }
# </style>
# <table id="T_28f95">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28f95_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_28f95_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_28f95_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_28f95_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_28f95_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_28f95_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_28f95_level0_col6" class="col_heading level0 col6" >MCC</th>
#       <th id="T_28f95_level0_col7" class="col_heading level0 col7" >APC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28f95_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_28f95_row0_col0" class="data row0 col0" >0.9745</td>
#       <td id="T_28f95_row0_col1" class="data row0 col1" >0.9779</td>
#       <td id="T_28f95_row0_col2" class="data row0 col2" >0.8261</td>
#       <td id="T_28f95_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_28f95_row0_col4" class="data row0 col4" >0.9048</td>
#       <td id="T_28f95_row0_col5" class="data row0 col5" >0.8902</td>
#       <td id="T_28f95_row0_col6" class="data row0 col6" >0.8956</td>
#       <td id="T_28f95_row0_col7" class="data row0 col7" >0.9432</td>
#     </tr>
#     <tr>
#       <th id="T_28f95_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_28f95_row1_col0" class="data row1 col0" >0.9745</td>
#       <td id="T_28f95_row1_col1" class="data row1 col1" >0.9828</td>
#       <td id="T_28f95_row1_col2" class="data row1 col2" >0.8696</td>
#       <td id="T_28f95_row1_col3" class="data row1 col3" >0.9524</td>
#       <td id="T_28f95_row1_col4" class="data row1 col4" >0.9091</td>
#       <td id="T_28f95_row1_col5" class="data row1 col5" >0.8943</td>
#       <td id="T_28f95_row1_col6" class="data row1 col6" >0.8956</td>
#       <td id="T_28f95_row1_col7" class="data row1 col7" >0.9581</td>
#     </tr>
#     <tr>
#       <th id="T_28f95_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_28f95_row2_col0" class="data row2 col0" >0.9873</td>
#       <td id="T_28f95_row2_col1" class="data row2 col1" >0.9977</td>
#       <td id="T_28f95_row2_col2" class="data row2 col2" >0.9130</td>
#       <td id="T_28f95_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_28f95_row2_col4" class="data row2 col4" >0.9545</td>
#       <td id="T_28f95_row2_col5" class="data row2 col5" >0.9472</td>
#       <td id="T_28f95_row2_col6" class="data row2 col6" >0.9485</td>
#       <td id="T_28f95_row2_col7" class="data row2 col7" >0.9899</td>
#     </tr>
#     <tr>
#       <th id="T_28f95_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_28f95_row3_col0" class="data row3 col0" >0.9745</td>
#       <td id="T_28f95_row3_col1" class="data row3 col1" >0.9893</td>
#       <td id="T_28f95_row3_col2" class="data row3 col2" >0.8696</td>
#       <td id="T_28f95_row3_col3" class="data row3 col3" >0.9524</td>
#       <td id="T_28f95_row3_col4" class="data row3 col4" >0.9091</td>
#       <td id="T_28f95_row3_col5" class="data row3 col5" >0.8943</td>
#       <td id="T_28f95_row3_col6" class="data row3 col6" >0.8956</td>
#       <td id="T_28f95_row3_col7" class="data row3 col7" >0.9629</td>
#     </tr>
#     <tr>
#       <th id="T_28f95_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_28f95_row4_col0" class="data row4 col0" >0.9618</td>
#       <td id="T_28f95_row4_col1" class="data row4 col1" >0.9494</td>
#       <td id="T_28f95_row4_col2" class="data row4 col2" >0.7826</td>
#       <td id="T_28f95_row4_col3" class="data row4 col3" >0.9474</td>
#       <td id="T_28f95_row4_col4" class="data row4 col4" >0.8571</td>
#       <td id="T_28f95_row4_col5" class="data row4 col5" >0.8353</td>
#       <td id="T_28f95_row4_col6" class="data row4 col6" >0.8404</td>
#       <td id="T_28f95_row4_col7" class="data row4 col7" >0.9093</td>
#     </tr>
#     <tr>
#       <th id="T_28f95_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_28f95_row5_col0" class="data row5 col0" >0.9936</td>
#       <td id="T_28f95_row5_col1" class="data row5 col1" >0.9905</td>
#       <td id="T_28f95_row5_col2" class="data row5 col2" >0.9545</td>
#       <td id="T_28f95_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_28f95_row5_col4" class="data row5 col4" >0.9767</td>
#       <td id="T_28f95_row5_col5" class="data row5 col5" >0.9730</td>
#       <td id="T_28f95_row5_col6" class="data row5 col6" >0.9734</td>
#       <td id="T_28f95_row5_col7" class="data row5 col7" >0.9745</td>
#     </tr>
#     <tr>
#       <th id="T_28f95_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_28f95_row6_col0" class="data row6 col0" >0.9808</td>
#       <td id="T_28f95_row6_col1" class="data row6 col1" >0.9783</td>
#       <td id="T_28f95_row6_col2" class="data row6 col2" >0.9091</td>
#       <td id="T_28f95_row6_col3" class="data row6 col3" >0.9524</td>
#       <td id="T_28f95_row6_col4" class="data row6 col4" >0.9302</td>
#       <td id="T_28f95_row6_col5" class="data row6 col5" >0.9191</td>
#       <td id="T_28f95_row6_col6" class="data row6 col6" >0.9194</td>
#       <td id="T_28f95_row6_col7" class="data row6 col7" >0.9457</td>
#     </tr>
#     <tr>
#       <th id="T_28f95_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_28f95_row7_col0" class="data row7 col0" >0.9615</td>
#       <td id="T_28f95_row7_col1" class="data row7 col1" >0.9813</td>
#       <td id="T_28f95_row7_col2" class="data row7 col2" >0.8636</td>
#       <td id="T_28f95_row7_col3" class="data row7 col3" >0.8636</td>
#       <td id="T_28f95_row7_col4" class="data row7 col4" >0.8636</td>
#       <td id="T_28f95_row7_col5" class="data row7 col5" >0.8412</td>
#       <td id="T_28f95_row7_col6" class="data row7 col6" >0.8412</td>
#       <td id="T_28f95_row7_col7" class="data row7 col7" >0.9455</td>
#     </tr>
#     <tr>
#       <th id="T_28f95_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_28f95_row8_col0" class="data row8 col0" >0.9936</td>
#       <td id="T_28f95_row8_col1" class="data row8 col1" >0.9990</td>
#       <td id="T_28f95_row8_col2" class="data row8 col2" >0.9545</td>
#       <td id="T_28f95_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_28f95_row8_col4" class="data row8 col4" >0.9767</td>
#       <td id="T_28f95_row8_col5" class="data row8 col5" >0.9730</td>
#       <td id="T_28f95_row8_col6" class="data row8 col6" >0.9734</td>
#       <td id="T_28f95_row8_col7" class="data row8 col7" >0.9945</td>
#     </tr>
#     <tr>
#       <th id="T_28f95_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_28f95_row9_col0" class="data row9 col0" >0.9487</td>
#       <td id="T_28f95_row9_col1" class="data row9 col1" >0.9579</td>
#       <td id="T_28f95_row9_col2" class="data row9 col2" >0.6818</td>
#       <td id="T_28f95_row9_col3" class="data row9 col3" >0.9375</td>
#       <td id="T_28f95_row9_col4" class="data row9 col4" >0.7895</td>
#       <td id="T_28f95_row9_col5" class="data row9 col5" >0.7611</td>
#       <td id="T_28f95_row9_col6" class="data row9 col6" >0.7736</td>
#       <td id="T_28f95_row9_col7" class="data row9 col7" >0.8898</td>
#     </tr>
#     <tr>
#       <th id="T_28f95_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_28f95_row10_col0" class="data row10 col0" >0.9751</td>
#       <td
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# 2024/08/03 00:41:03 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# CPU times: total: 5.03 s
# Wall time: 1h 13min 42s

# %%
result = predict_model(tuned_vote, raw_score=True, data=df_test)

# %%
save_model(tuned_vote, 'tuned_vote')
