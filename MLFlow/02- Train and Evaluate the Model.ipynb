# %%
import numpy as np
import pandas as pd
import os

from sklearn.metrics import average_precision_score

import pycaret
from pycaret.classification import *
from infra_utils import get_raw_data

# %%
data_file = ('dataset' +  os.path.sep +  'creditcard.csv')
data_file
# Out:
# 'dataset\\creditcard.csv'

# %%
df = pd.read_csv(data_file)

# %%
df_train, df_test = get_raw_data(df)

# %%
# df_train.head(2)

# %%
# %%time
clf1 = pycaret.classification.setup(data=df_train,
                                    target='target',
                                     verbose=False,
                                     log_experiment=True,
                                     use_gpu=False,
                                     experiment_name='selected_model',
                                     fix_imbalance=True,
                                     #transformation=True,
                                     polynomial_features=True
                                    )


pycaret.classification.add_metric('apc', 'APC', average_precision_score, target='pred_proba')

best_model = pycaret.classification.compare_models(sort='APC',
                                                   # include=['lightgbm', 'et', 'rf', 'lr', 'gbc'],
                                                   include=['et', 'rf', 'lr', 'gbc'],
                                                   probability_threshold=0.5
                                                  )
# Out:
# <style type="text/css">
# #T_3b257 th {
#   text-align: left;
# }
# #T_3b257_row0_col0, #T_3b257_row0_col1, #T_3b257_row0_col4, #T_3b257_row0_col5, #T_3b257_row0_col6, #T_3b257_row0_col7, #T_3b257_row1_col0, #T_3b257_row1_col2, #T_3b257_row1_col3, #T_3b257_row1_col8, #T_3b257_row2_col0, #T_3b257_row2_col1, #T_3b257_row2_col2, #T_3b257_row2_col3, #T_3b257_row2_col4, #T_3b257_row2_col5, #T_3b257_row2_col6, #T_3b257_row2_col7, #T_3b257_row2_col8, #T_3b257_row3_col0, #T_3b257_row3_col1, #T_3b257_row3_col2, #T_3b257_row3_col3, #T_3b257_row3_col4, #T_3b257_row3_col5, #T_3b257_row3_col6, #T_3b257_row3_col7, #T_3b257_row3_col8 {
#   text-align: left;
# }
# #T_3b257_row0_col2, #T_3b257_row0_col3, #T_3b257_row0_col8, #T_3b257_row1_col1, #T_3b257_row1_col4, #T_3b257_row1_col5, #T_3b257_row1_col6, #T_3b257_row1_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_3b257_row0_col9, #T_3b257_row1_col9, #T_3b257_row3_col9 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_3b257_row2_col9 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_3b257">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3b257_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3b257_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_3b257_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_3b257_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_3b257_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_3b257_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_3b257_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_3b257_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_3b257_level0_col8" class="col_heading level0 col8" >APC</th>
#       <th id="T_3b257_level0_col9" class="col_heading level0 col9" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b257_level0_row0" class="row_heading level0 row0" >gbc</th>
#       <td id="T_3b257_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_3b257_row0_col1" class="data row0 col1" >0.9699</td>
#       <td id="T_3b257_row0_col2" class="data row0 col2" >0.9835</td>
#       <td id="T_3b257_row0_col3" class="data row0 col3" >0.8794</td>
#       <td id="T_3b257_row0_col4" class="data row0 col4" >0.9123</td>
#       <td id="T_3b257_row0_col5" class="data row0 col5" >0.8932</td>
#       <td id="T_3b257_row0_col6" class="data row0 col6" >0.8758</td>
#       <td id="T_3b257_row0_col7" class="data row0 col7" >0.8775</td>
#       <td id="T_3b257_row0_col8" class="data row0 col8" >0.9576</td>
#       <td id="T_3b257_row0_col9" class="data row0 col9" >14.4200</td>
#     </tr>
#     <tr>
#       <th id="T_3b257_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_3b257_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_3b257_row1_col1" class="data row1 col1" >0.9770</td>
#       <td id="T_3b257_row1_col2" class="data row1 col2" >0.9821</td>
#       <td id="T_3b257_row1_col3" class="data row1 col3" >0.8662</td>
#       <td id="T_3b257_row1_col4" class="data row1 col4" >0.9728</td>
#       <td id="T_3b257_row1_col5" class="data row1 col5" >0.9136</td>
#       <td id="T_3b257_row1_col6" class="data row1 col6" >0.9005</td>
#       <td id="T_3b257_row1_col7" class="data row1 col7" >0.9042</td>
#       <td id="T_3b257_row1_col8" class="data row1 col8" >0.9515</td>
#       <td id="T_3b257_row1_col9" class="data row1 col9" >1.5550</td>
#     </tr>
#     <tr>
#       <th id="T_3b257_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_3b257_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_3b257_row2_col1" class="data row2 col1" >0.9757</td>
#       <td id="T_3b257_row2_col2" class="data row2 col2" >0.9780</td>
#       <td id="T_3b257_row2_col3" class="data row2 col3" >0.8704</td>
#       <td id="T_3b257_row2_col4" class="data row2 col4" >0.9608</td>
#       <td id="T_3b257_row2_col5" class="data row2 col5" >0.9097</td>
#       <td id="T_3b257_row2_col6" class="data row2 col6" >0.8958</td>
#       <td id="T_3b257_row2_col7" class="data row2 col7" >0.8995</td>
#       <td id="T_3b257_row2_col8" class="data row2 col8" >0.9469</td>
#       <td id="T_3b257_row2_col9" class="data row2 col9" >0.9240</td>
#     </tr>
#     <tr>
#       <th id="T_3b257_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_3b257_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_3b257_row3_col1" class="data row3 col1" >0.9668</td>
#       <td id="T_3b257_row3_col2" class="data row3 col2" >0.9563</td>
#       <td id="T_3b257_row3_col3" class="data row3 col3" >0.8751</td>
#       <td id="T_3b257_row3_col4" class="data row3 col4" >0.8930</td>
#       <td id="T_3b257_row3_col5" class="data row3 col5" >0.8822</td>
#       <td id="T_3b257_row3_col6" class="data row3 col6" >0.8629</td>
#       <td id="T_3b257_row3_col7" class="data row3 col7" >0.8641</td>
#       <td id="T_3b257_row3_col8" class="data row3 col8" >0.9248</td>
#       <td id="T_3b257_row3_col9" class="data row3 col9" >1.3130</td>
#     </tr>
#   </tbody>
# </table>
# 2024/08/02 17:52:39 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 2024/08/02 17:52:40 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 2024/08/02 17:52:40 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 2024/08/02 17:52:40 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# CPU times: total: 1min 24s
# Wall time: 4min 26s

# %%
best_model
# Out:
# CustomProbabilityThresholdClassifier(ccp_alpha=0.0,
#                                      classifier=GradientBoostingClassifier(ccp_alpha=0.0,
#                                                                            criterion='friedman_mse',
#                                                                            init=None,
#                                                                            learning_rate=0.1,
#                                                                            loss='log_loss',
#                                                                            max_depth=3,
#                                                                            max_features=None,
#                                                                            max_leaf_nodes=None,
#                                                                            min_impurity_decrease=0.0,
#                                                                            min_samples_leaf=1,
#                                                                            min_samples_split=2,
#                                                                            min_weight_fraction_leaf=0.0,
#                                                                            n_estimators=100,
#                                                                            n_iter_no_change=...
#                                      criterion='friedman_mse', init=None,
#                                      learning_rate=0.1, loss='log_loss',
#                                      max_depth=3, max_features=None,
#                                      max_leaf_nodes=None,
#                                      min_impurity_decrease=0.0,
#                                      min_samples_leaf=1, min_samples_split=2,
#                                      min_weight_fraction_leaf=0.0,
#                                      n_estimators=100, n_iter_no_change=None,
#                                      probability_threshold=0.5,
#                                      random_state=1220, subsample=1.0,
#                                      tol=0.0001, validation_fraction=0.1,
#                                      verbose=0, warm_start=False)

# %%
pycaret.classification.evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
plot_model(best_model, plot='pr')

# %%
plot_model(best_model, 'manifold')

# %%
plot_model(best_model, plot='feature')
